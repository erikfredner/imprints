# %% [markdown]
# # Visualizing the LC place of publication data

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd

# %%
plt.style.use("seaborn-v0_8-colorblind")
plt.rcParams["font.family"] = "Helvetica"
plt.rcParams["figure.figsize"] = [3.54 * 2, 3.54]

# %%
df = pd.read_csv("../data/data.csv")

# %%
plot_df = (
    df[(df["min_year"] >= 1750) & (df["min_year"] <= 1920)]
    .groupby(["min_year", "target_city"])
    .size()
    .unstack()
    .fillna(0)
    .rolling(5)
    .mean()
)

# %%
ax = plot_df.plot(kind="line")

# Reorder legend
handles, labels = ax.get_legend_handles_labels()
order = [1, 0, 4, 3, 2]
ax.legend([handles[idx] for idx in order], [labels[idx] for idx in order], title="City")

ax.set_ylabel("LC American Literature books")
ax.set_xlabel("Year")
ax.set_title("LC US Literature books by place of publication")
ax.figure.tight_layout()
ax.figure.savefig("../results/lc_ps.png", dpi=600)

# %%
plot_df = (
    df[(df["min_year"] >= 1816) & (df["min_year"] <= 1920)]
    .groupby(["min_year", "target_city"])
    .size()
    .unstack()
    .fillna(0)
    .rolling(5)
    .mean()
)

# %%
# normalize values
plot_df = plot_df.div(plot_df.sum(axis=1), axis=0) * 100

# %%
ax = plot_df.plot(kind="line")

# Reorder legend
handles, labels = ax.get_legend_handles_labels()
order = [1, 0, 4, 3, 2]
ax.legend(
    [handles[idx] for idx in order],
    [labels[idx] for idx in order],
    title="City",
    loc="center left",
    bbox_to_anchor=(1, 0.5),
)

ax.set_ylabel("% LC US literature books")
ax.set_xlabel("Year")
ax.set_title("% LC US Literature books by place of publication")
ax.figure.tight_layout()
ax.figure.savefig("../results/lc_ps_pct.png", dpi=600)

# %%
ax = plot_df.plot.area()

# Reorder legend
handles, labels = ax.get_legend_handles_labels()
order = [1, 0, 4, 3, 2]
ax.legend(
    [handles[idx] for idx in order],
    [labels[idx] for idx in order],
    title="City",
    loc="center left",
    bbox_to_anchor=(1, 0.5),
)

ax.set_ylabel("% LC US literature books")
ax.set_xlabel("Year")
ax.set_title("% LC US Literature books by place of publication")
ax.figure.tight_layout()
ax.figure.savefig("../results/lc_ps_pct_area.png", dpi=600)
